# %%
nums = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print(nums[1:4])
# Out:
# [2, 3, 4]

# %%
x = "madan"
if x == x[::-1]:
    print("palindram")

else:
    print("not a plindram")
# Out:
# not a plindram

# %%
Student_name = 'Sai'
Student_age = 32
student_grade = 'A'

print(Student_name + "\n" + str(Student_age) + "\n" + student_grade)
# Out:
# Sai
# 32
# A
