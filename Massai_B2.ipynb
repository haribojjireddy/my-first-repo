# %% [markdown]
# <a href="https://colab.research.google.com/github/haribojjireddy/my-first-repo/blob/main/Massai_B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# hi for test

# %%
print("hello")
# Out:
# hello

# %%
numbers=(4,5,6,19,34,56)
for i in numbers:
  i = i + 0
  print(i)
# Out:
# 4
# 5
# 6
# 19
# 34
# 56

# %%
for i in range(3):
    print("outer:", i)
    for j in range(2):
        print("inner:", j)
# Out:
# outer: 0
# inner: 0
# inner: 1
# outer: 1
# inner: 0
# inner: 1
# outer: 2
# inner: 0
# inner: 1

# %%
while True:
    print("Running...")
# Out:
# Streaming output truncated to the last 5000 lines.
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# ...

# %%
def greet():
    print("Hello!")
    print("Welcome.")

# %%
greet()
# Out:
# Hello!
# Welcome.

# %%
for i in range(0,3,1):
    for j in range (0,2,1):
        print (i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %% [markdown]
# Write a for loop that prints numbers from 1 to 7. If the number is 5, stop the loop immediately using break.

# %%
for i in range(1,7,1):
  if i == 5:
    break
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Write a for loop that prints only odd numbers between 1 and 10 using the step parameter in range().

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# Write a for loop that prints all numbers from 1 to 5 using range().

# %%
for i in range(1,6):

      print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def create_profile(name, age, city="Unknown"):
    print(f"{name}, {age} from {city}")

# %%
create_profile("madan",42)
# Out:
# madan, 42 from Unknown

# %%
def add_numbers(a, b):
    print(a + b)   # This prints the sum but does not return it

result = add_numbers(5, 10)
print(result)
# Out:
# 15
# None

# %%
def add_numbers(a, b):
    print(a + b)

result = add_numbers(5, 10)
print(result)
# Out:
# 15
# None

# %%
def calculate_total(marks):
     total = sum(marks)
     return total

# %%
calculate_total(100,98,9)

# %%
test = [45,23,54,87,34,52]
print(test)
# Out:
# [45, 23, 54, 87, 34, 52]

# %%
test.append(100)
print(test)
# Out:
# [45, 23, 54, 87, 34, 52, 100]

# %%
test.insert(2,200)
print(test)
# Out:
# [45, 23, 200, 54, 87, 34, 52, 100]

# %%
test.pop()
print(test)
# Out:
# [45, 23, 200, 54, 87, 34, 52]

# %%
test.remove(45)
print(test)
# Out:
# [23, 200, 54, 87, 34, 52]

# %%
fruits = ('apple', 'banana', 'cherry')
for index, value in enumerate(fruits):
    print(index, value)
# Out:
# 0 apple
# 1 banana
# 2 cherry

# %%
single = (1)
print(type(single))
# Out:
# <class 'int'>

# %%
import subprocess
result = subprocess.run('whoami', shell=True, capture_output=True, text=True)
print(result.stdout)
# Out:
# root

# %% [markdown]
# Task 1 — Tuples Create a tuple of five city names, unpack it into five separate variables, and print each variable. Then try to modify the first element and handle the resulting error with a try-except block that prints a clear message.

# %%
citynames = ("bangalore","hyderabad","chennai","kolkata","Tiruchi")
for city in citynames:
    print(city)

try:
    city[0]= "shelam"   # Tuples are immutable, so this will raise an error

except TypeError as e:
    print("Error: Tuples are immutable. You cannot modify elements.")
    print("Details:", e)
# Out:
# bangalore
# hyderabad
# chennai
# kolkata
# Tiruchi
# Error: Tuples are immutable. You cannot modify elements.
# Details: 'str' object does not support item assignment

# %% [markdown]
# Sets Create two sets — one for students who passed a Python test and one for students who passed a SQL test. Print the union, intersection, and difference (Python-only passers) using set operators.

# %%
# Create two sets
python_pass = {"Alice", "Bob", "Charlie", "David"}
sql_pass = {"Charlie", "Eve", "Bob", "Frank"}

# Union: students who passed either Python or SQL
print("Students who passed Python or SQL:", python_pass | sql_pass)

# Intersection: students who passed both Python and SQL
print("Students who passed both tests:", python_pass & sql_pass)

# Difference: students who passed Python only
print("Students who passed only Python:", python_pass - sql_pass)
# Out:
# Students who passed Python or SQL: {'Eve', 'Alice', 'Bob', 'Charlie', 'Frank', 'David'}
# Students who passed both tests: {'Bob', 'Charlie'}
# Students who passed only Python: {'Alice', 'David'}

# %% [markdown]
# Lists and ASCII Create a list of five integers representing ASCII values. Use a loop with chr() to print each integer alongside its corresponding character. Then use ord() to retrieve and print the ASCII value of the character 'Z'.

# %%
# Create a list of ASCII values
ascii_values = [65, 66, 67, 68, 69]

# Print each integer with its character
for value in ascii_values:
    print(value, chr(value))

# Print ASCII value of 'Z'
print(ord('Z'))
# Out:
# 65 A
# 66 B
# 67 C
# 68 D
# 69 E
# 90

# %% [markdown]
# Subprocess Use the subprocess module to run the shell command whoami and print the captured output using result.stdout.

# %%
import subprocess

# Run the command and capture output
result = subprocess.run("whoami", shell=True, capture_output=True, text=True)

# Print the captured output
print("Current user:", result.stdout.strip())
# Out:
# Current user: root

# %%
numbers = (10, 33, 7, 80, 55, 2)
numbers=sorted(numbers)
print(numbers)
# Out:
# [2, 7, 10, 33, 55, 80]

# %%
numbers = (10, 33, 7, 80, 55, 2)
numbers=tuple(sorted(numbers))
print(numbers)
# Out:
# (2, 7, 10, 33, 55, 80)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_7970/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...
