# %%
import sys
print(sys.executable)
# Out:
# c:\Users\ebojmad\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
# !pip show pandas
# Out:
# WARNING: Package(s) not found: pandas

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\ebojmad\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.2-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.4.4-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
# Using cached pandas-3.0.2-cp314-cp314-win_amd64.whl (9.9 MB)
# Using cached numpy-2.4.4-cp314-cp314-win_amd64.whl (12.4 MB)
# ...
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
# ...

# %%
import pandas as pd
print("hello world")
print(pd.__version__)
# Out:
# hello world
# 3.0.2
